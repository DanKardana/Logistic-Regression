# %%
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression

GPT = pd.read_excel('INFS5720-Team Project Data updated.xlsx')
GPT
# Out:
#       Location Name  Year Occurred_On  Total_Potable_Water  \
# 0        Logistics1  2022  2022-12-01             231.6667
# 1        Logistics1  2021  2021-05-01               0.0000
# 2        Logistics1  2019  2019-12-01               0.0000
# 3        Logistics1  2018  2018-01-01               0.0000
# 4        Logistics1  2021  2021-06-01               0.0000
# ...             ...   ...         ...                  ...
# 35862       Retail5  2018  2018-12-01               0.0000
# 35863       Retail5  2020  2020-04-01               0.0000
# 35864       Retail5  2018  2018-05-01               0.0000
# 35865       Retail5  2019  2019-08-01               0.0000
# 35866       Retail5  2019  2019-06-01            4830.5552
#
#        Total_NonPotable_Water  Total_Water  Water_Intensity  Landfill  \
# 0                         0.0     231.6667        26.822589     0.000
# 1                         0.0       0.0000         0.000000     0.000
# ...

# %%
import pandas as pd

# Assuming 'GPT' is the DataFrame containing the data
columns_to_check = ['Net_Emission', 'Total_Material_Generated', 'Total_Energy_Use', 'Total_Water']

# Filtering out rows with 0 values in the specified columns
GPT = GPT[(GPT[columns_to_check] != 0).all(axis=1)]

# Reset the index of the DataFrame if needed
GPT.reset_index(drop=True, inplace=True)

# %%
print(GPT.columns)
GPT
# Out:
# Index([                  'Location Name',                            'Year',
#                            'Occurred_On',             'Total_Potable_Water',
#                 'Total_NonPotable_Water',                     'Total_Water',
#                        'Water_Intensity',                        'Landfill',
#                                'A_Grade',                         'B_Grade',
#                                'C_Grade',        'Total_Material_Generated',
#        'Electricity_Estimated_Unit_Cost',         'Gas_Estimated_Unit_Cost',
#                                    'NLA',                                 1,
#                 'Total_Renewable_Energy',                'Total_Energy_Use',
#                       'Energy_Intensity',               'Scope_1_emissions',
#                      'Scope_2_emissions',               'Scope_1_Intensity',
#                      'Scope_2_Intensity',                   'Total_Offsets',
# ...

# %%
# Creating the linear models & model testing

#Model = smf.ols(formula = 'Net_Emission ~ Energy_Intensity + Total_Renewable_Energy + Total_NonRenewable_Energy + Total_Offsets', data = GPT).fit()
Model1 = smf.ols(formula = 'Net_Emission ~ Total_Material_Generated + Total_Energy_Use + Total_Water', data = GPT).fit()
#Model2 = smf.ols(formula = 'Emissions_Avoided ~ A_Grade + B_Grade + Landfill', data = GPT).fit()
#Model.summary()
Model1.summary()
#Model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Net_Emission   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                 2.028e+04
# Date:                Sat, 29 Jul 2023   Prob (F-statistic):               0.00
# Time:                        17:54:08   Log-Likelihood:            -2.2102e+05
# No. Observations:               35855   AIC:                         4.420e+05
# Df Residuals:                   35851   BIC:                         4.421e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...
